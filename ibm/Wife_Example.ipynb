# %% [markdown]
# This is my first Python Program

# %%
print("Hello Wife!")
# Out:
# Hello Wife!

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
X=np.linspace(0,8*np.pi,num=25)
Y=np.sin(X)

plt.plot(X,Y)
