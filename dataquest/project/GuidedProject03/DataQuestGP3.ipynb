# %% [markdown]
# # Guided Project #3 - Ebay Car Sales
# By [Luis Munguia](http://www.linkedin.com/in/luis-munguia) and [Dataquest](http://www.dataquest.io)
#
# In this guided project, I'll work with a dataset on car sales from *eBay Kelinanzeigen* (Germany here I go!). This data was scraped and uploaded to Kaggle but here it's been dirtied to closely resemble what I would expect from a scraped dataset. Also, only 50,000 data points were sampled from the full dataset.
#
# The data dictionary is as follows:
#
# * `dateCrawled`: When this ad was first crawled. All field-values are taken from this date.
# * `name`: Name of the car.
# * `seller`: Whether the seller is private or a dealer.
# * `offerType`: The type of listing.
# * `price`: The price on the ad to sell the car.
# * `abtest`: Whether the listing is included in an A/B test.
# * `vehicleType`: The vehicle Type.
# * `yearOfRegistration`: The year in which which year the car was first registered.
# * `gearbox`: The transmission type.
# * `powerPS`: The power of the car in PS.
# * `model`: The car model name.
# * `kilometer`: How many kilometers the car has driven.
# * `monthOfRegistration`: The month in which which year the car was first registered.
# * `fuelType`: What type of fuel the car uses.
# * `brand`: The brand of the car.
# * `notRepairedDamage`: If the car has a damage which is not yet repaired.
# * `dateCreated`: The date on which the eBay listing was created.
# * `nrOfPictures`: The number of pictures in the ad.
# * `postalCode`: The postal code for the location of the vehicle.
# * `lastSeenOnline`: When the crawler saw this ad last online.
#
# This project's aim is to clean the data and analyze used car listings.

# %% [markdown]
# ## 1.- Use pandas and NumPy libraries.
#
# Use pandas to import data from `autos.csv` and display data.

# %%
import pandas as pd
import numpy as np

autos = pd.read_csv("autos.csv", encoding = "Latin-1" ) #Unicode failed the fist time (UTF-8)
autos                                                   #Changed to Latin-1
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# 11     2016-03-16 18:45:34                         Mercedes_A140_Motorschaden
# 12     2016-03-31 19:48:22  Smart_smart_fortwo_coupe_softouch_pure_MHD_Pan...
# 13     2016-03-23 10:48:32                                 Audi_A3_1.6_tuning
# 14     2016-03-23 11:50:46  Renault_Clio_3__Dynamique_1.2__16_V;_viele_Ver...
# 15     2016-04-01 12:06:20        Corvette_C3_Coupe_T_Top_Crossfire_Injection
# 16     2016-03-16 14:59:02                                Opel_Vectra_B_Kombi
# 17     2016-03-29 11:46:22                          Volkswagen_Scirocco_2_G60
# 18     2016-03-26 19:57:44               Verkaufen_mein_bmw_e36_320_i_touring
# 19     2016-03-17 13:36:21        mazda_tribute_2.0_mit_gas_und_tuev_neu_2018
# 20     2016-03-05 19:57:31  Audi_A4_Avant_1.9_TDI_*6_Gang*AHK*Klimatronik*...
# 21     2016-03-06 19:07:10                      Porsche_911_Carrera_4S_Cabrio
# 22     2016-03-28 20:50:54                               MINI_Cooper_S_Cabrio
# 23     2016-03-10 19:55:34   Peugeot_Boxer_2_2_HDi_120_Ps_9_Sitzer_inkl_Klima
# 24     2016-04-03 11:57:02                         BMW_535i_xDrive_Sport_Aut.
# 25     2016-03-21 21:56:18  Ford_escort_kombi_an_bastler_mit_ghia_ausstattung
# 26     2016-04-03 22:46:28                                Volkswagen_Polo_Fox
# 27     2016-03-27 18:45:01             Hat_einer_Ahnung_mit_Ford_Galaxy_HILFE
# 28     2016-03-19 21:56:19                                      MINI_Cooper_D
# 29     2016-04-02 12:45:44  Mercedes_Benz_E_320_T_CDI_Avantgarde_DPF7_Sitz...
# ...                    ...                                                ...
# 49970  2016-03-21 22:47:37  c4_Grand_Picasso_mit_Automatik_Leder_Navi_Temp...
# 49971  2016-03-29 14:54:12                                         W.Lupo_1.0
# 49972  2016-03-26 22:25:23          Mercedes_Benz_Vito_115_CDI_Extralang_Aut.
# 49973  2016-03-27 05:32:39                   Mercedes_Benz_SLK_200_Kompressor
# 49974  2016-03-20 10:52:31  Golf_1_Cabrio_Tuev_Neu_viele_Extras_alles_eing...
# 49975  2016-03-27 20:51:39          Honda_Jazz_1.3_DSi_i_VTEC_IMA_CVT_Comfort
# 49976  2016-03-19 18:56:05  Audi_80_Avant_2.6_E__Vollausstattung!!_Einziga...
# 49977  2016-03-31 18:37:18                        Mercedes_Benz_C200_Cdi_W203
# 49978  2016-04-04 10:37:14                        Mercedes_Benz_E_200_Classic
# 49979  2016-03-20 18:38:40                      Volkswagen_Polo_1.6_TDI_Style
# 49980  2016-03-12 10:55:54                            Ford_Escort_Turnier_16V
# 49981  2016-03-15 09:38:21             Opel_Astra_Kombi_mit_Anhaengerkupplung
# 49982  2016-03-29 18:51:08            Skoda_Fabia_4_Tuerer_Bj:2004__85.000Tkm
# 49983  2016-03-06 12:43:04                                      Ford_focus_99
# 49984  2016-03-31 22:48:48  Student_sucht_ein__Anfaengerauto___ab_2000_BJ_...
# 49985  2016-04-02 16:38:23                          Verkaufe_meinen_vw_vento!
# 49986  2016-04-04 20:46:02  Chrysler_300C_3.0_CRD_DPF_Automatik_Voll_Ausst...
# 49987  2016-03-22 20:47:27  Audi_A3_Limousine_2.0_TDI_DPF_Ambition__NAVI__...
# 49988  2016-03-28 19:49:51                                         BMW_330_Ci
# 49989  2016-03-11 19:50:37        VW_Polo_zum_Ausschlachten_oder_Wiederaufbau
# 49990  2016-03-21 19:54:19         Mercedes_Benz_A_200__BlueEFFICIENCY__Urban
# 49991  2016-03-06 15:25:19                                         Kleinwagen
# 49992  2016-03-10 19:37:38              Fiat_Grande_Punto_1.4_T_Jet_16V_Sport
# 49993  2016-03-15 18:47:35           Audi_A3__1_8l__Silber;_schoenes_Fahrzeug
# 49994  2016-03-22 17:36:42  Audi_A6__S6__Avant_4.2_quattro_eventuell_Tausc...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
#        seller offerType    price   abtest vehicleType  yearOfRegistration  \
# 0      privat   Angebot   $5,000  control         bus                2004
# 1      privat   Angebot   $8,500  control   limousine                1997
# 2      privat   Angebot   $8,990     test   limousine                2009
# 3      privat   Angebot   $4,350  control  kleinwagen                2007
# 4      privat   Angebot   $1,350     test       kombi                2003
# 5      privat   Angebot   $7,900     test         bus                2006
# 6      privat   Angebot     $300     test   limousine                1995
# 7      privat   Angebot   $1,990  control   limousine                1998
# 8      privat   Angebot     $250     test         NaN                2000
# 9      privat   Angebot     $590  control         bus                1997
# 10     privat   Angebot     $999     test         NaN                2017
# 11     privat   Angebot     $350  control         NaN                2000
# 12     privat   Angebot   $5,299  control  kleinwagen                2010
# 13     privat   Angebot   $1,350  control   limousine                1999
# 14     privat   Angebot   $3,999     test  kleinwagen                2007
# 15     privat   Angebot  $18,900     test       coupe                1982
# 16     privat   Angebot     $350     test       kombi                1999
# 17     privat   Angebot   $5,500     test       coupe                1990
# 18     privat   Angebot     $300  control         bus                1995
# 19     privat   Angebot   $4,150  control         suv                2004
# 20     privat   Angebot   $3,500     test       kombi                2003
# 21     privat   Angebot  $41,500     test      cabrio                2004
# 22     privat   Angebot  $25,450  control      cabrio                2015
# 23     privat   Angebot   $7,999  control         bus                2010
# 24     privat   Angebot  $48,500  control   limousine                2014
# 25     privat   Angebot      $90  control       kombi                1996
# 26     privat   Angebot     $777  control  kleinwagen                1992
# 27     privat   Angebot       $0  control         NaN                2005
# 28     privat   Angebot   $5,250  control  kleinwagen                2007
# 29     privat   Angebot   $4,999     test       kombi                2004
# ...       ...       ...      ...      ...         ...                 ...
# 49970  privat   Angebot  $15,800  control         bus                2010
# 49971  privat   Angebot     $950     test  kleinwagen                2001
# 49972  privat   Angebot   $3,300  control         bus                2004
# 49973  privat   Angebot   $6,000  control      cabrio                2004
# 49974  privat   Angebot       $0  control      cabrio                1983
# 49975  privat   Angebot   $9,700  control  kleinwagen                2012
# 49976  privat   Angebot   $5,900     test       kombi                1992
# 49977  privat   Angebot   $5,500  control   limousine                2003
# 49978  privat   Angebot     $900  control   limousine                1996
# 49979  privat   Angebot  $11,000     test  kleinwagen                2011
# 49980  privat   Angebot     $400  control       kombi                1995
# 49981  privat   Angebot   $2,000  control       kombi                1998
# 49982  privat   Angebot   $1,950  control  kleinwagen                2004
# 49983  privat   Angebot     $600     test  kleinwagen                1999
# 49984  privat   Angebot       $0     test         NaN                2000
# 49985  privat   Angebot   $1,000  control         NaN                1995
# 49986  privat   Angebot  $15,900  control   limousine                2010
# 49987  privat   Angebot  $21,990  control   limousine                2013
# 49988  privat   Angebot   $9,550  control       coupe                2001
# 49989  privat   Angebot     $150     test  kleinwagen                1997
# 49990  privat   Angebot  $17,500     test   limousine                2012
# 49991  privat   Angebot     $500  control         NaN                2016
# 49992  privat   Angebot   $4,800  control  kleinwagen                2009
# 49993  privat   Angebot   $1,650  control  kleinwagen                1997
# 49994  privat   Angebot   $5,000  control       kombi                2001
# 49995  privat   Angebot  $24,900  control   limousine                2011
# 49996  privat   Angebot   $1,980  control      cabrio                1996
# 49997  privat   Angebot  $13,200     test      cabrio                2014
# 49998  privat   Angebot  $22,900  control       kombi                2013
# 49999  privat   Angebot   $1,250  control   limousine                1996
#
#          gearbox  powerPS     model   odometer  monthOfRegistration fuelType  \
# 0        manuell      158    andere  150,000km                    3      lpg
# 1      automatik      286       7er  150,000km                    6   benzin
# 2        manuell      102      golf   70,000km                    7   benzin
# 3      automatik       71    fortwo   70,000km                    6   benzin
# 4        manuell        0     focus  150,000km                    7   benzin
# 5      automatik      150   voyager  150,000km                    4   diesel
# 6        manuell       90      golf  150,000km                    8   benzin
# 7        manuell       90      golf  150,000km                   12   diesel
# 8        manuell        0     arosa  150,000km                   10      NaN
# 9        manuell       90    megane  150,000km                    7   benzin
# 10       manuell       90       NaN  150,000km                    4   benzin
# 11           NaN        0       NaN  150,000km                    0   benzin
# 12     automatik       71    fortwo   50,000km                    9   benzin
# 13       manuell      101        a3  150,000km                   11   benzin
# 14       manuell       75      clio  150,000km                    9   benzin
# 15     automatik      203       NaN   80,000km                    6   benzin
# 16       manuell      101    vectra  150,000km                    5   benzin
# 17       manuell      205  scirocco  150,000km                    6   benzin
# 18       manuell      150       3er  150,000km                    0   benzin
# 19       manuell      124    andere  150,000km                    2      lpg
# 20       manuell      131        a4  150,000km                    5   diesel
# 21       manuell      320       911  150,000km                    4   benzin
# 22       manuell      184    cooper   10,000km                    1   benzin
# 23       manuell      120       NaN  150,000km                    2   diesel
# 24     automatik      306       5er   30,000km                   12   benzin
# 24          22547  2016-04-07 13:16:50
# 25          27574  2016-04-01 05:16:49
# 26          38110  2016-04-05 23:46:48
# 27          66701  2016-03-27 18:45:01
# 28          15745  2016-04-07 14:58:48
# 29          47638  2016-04-02 12:45:44
# ...           ...                  ...
# 49970       14947  2016-04-07 04:17:34
# 49971       65197  2016-03-29 20:41:51
# 49972       65326  2016-03-28 11:28:18
# 49973       53567  2016-03-27 08:25:24
# 49974        8209  2016-03-27 19:48:16
# 49975       84385  2016-04-05 19:45:34
# 49976       36100  2016-04-07 06:16:44
# 49977       33739  2016-04-06 12:16:11
# 49978       24405  2016-04-06 12:44:20
# 49979       48455  2016-04-07 01:45:12
# 49980       56218  2016-04-06 17:16:49
# 49981       86859  2016-04-05 17:21:46
# 49982       45884  2016-03-29 18:51:08
# 49983       52477  2016-03-09 06:16:08
# 49984       12103  2016-04-02 19:44:53
# 49985       30900  2016-04-06 15:17:52
# 49986       73527  2016-04-06 23:16:00
# 49987       94362  2016-03-26 22:46:06
# 49988       83646  2016-04-07 02:17:40
# 49989       21244  2016-03-12 10:17:55
# 49990       58239  2016-04-06 22:46:57
# 49991       61350  2016-03-06 18:24:19
# 49992       68642  2016-03-13 01:44:51
# 49993       65203  2016-04-06 19:46:53
# 49994       46537  2016-04-06 08:16:39
# 49995       82131  2016-04-01 13:47:40
# 49996       44807  2016-04-02 14:18:02
# 49997       73430  2016-04-04 11:47:27
# 49998       35683  2016-04-05 16:45:07
# 49999       45897  2016-04-06 21:18:48
#
# [50000 rows x 20 columns]

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# postalCode             50000 non-null int64
# lastSeen               50000 non-null object
# dtypes: int64(5), object(15)
# memory usage: 7.6+ MB

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# 0    manuell      158  andere  150,000km                    3      lpg
# 1  automatik      286     7er  150,000km                    6   benzin
# 2    manuell      102    golf   70,000km                    7   benzin
# 3  automatik       71  fortwo   70,000km                    6   benzin
# 4    manuell        0   focus  150,000km                    7   benzin
#
#         brand notRepairedDamage          dateCreated  nrOfPictures  \
# 0     peugeot              nein  2016-03-26 00:00:00             0
# 1         bmw              nein  2016-04-04 00:00:00             0
# 2  volkswagen              nein  2016-03-26 00:00:00             0
# 3       smart              nein  2016-03-12 00:00:00             0
# 4        ford              nein  2016-04-01 00:00:00             0
#
#    postalCode             lastSeen
# 0       79588  2016-04-06 06:45:54
# 1       71034  2016-04-06 14:45:08
# 2       35394  2016-04-06 20:15:37
# 3       33729  2016-03-15 03:16:28
# 4       39218  2016-04-01 14:38:50

# %% [markdown]
# Data is not sorted, I'm missing data from 5 columns, and language seems to be deutsch in some cases.

# %% [markdown]
# ## 2.- Change column names from camelCase to snake_case.
#
# Change column display type and generalize names.

# %%
camelCase = autos.columns

# %%
camelCase
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
snake_case = ['date_crawled', 'name', 'seller', 'offer_type', 'price', 'ab_test', 'vehicle_type',
              'registration_year', 'gear_box', 'power_PS', 'model', 'odometer',
              'registration_month', 'fuel_type', 'brand', 'unrepaired_damage', 'ad_created',
              'nr_of_pictures', 'postal_code', 'last_seen']

# %%
autos.columns = snake_case

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price  ab_test vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#     gear_box  power_PS   model   odometer  registration_month fuel_type  \
# 0    manuell       158  andere  150,000km                   3       lpg
# 1  automatik       286     7er  150,000km                   6    benzin
# 2    manuell       102    golf   70,000km                   7    benzin
# 3  automatik        71  fortwo   70,000km                   6    benzin
# 4    manuell         0   focus  150,000km                   7    benzin
#
#         brand unrepaired_damage           ad_created  nr_of_pictures  \
# 0     peugeot              nein  2016-03-26 00:00:00               0
# 1         bmw              nein  2016-04-04 00:00:00               0
# 2  volkswagen              nein  2016-03-26 00:00:00               0
# 3       smart              nein  2016-03-12 00:00:00               0
# 4        ford              nein  2016-04-01 00:00:00               0
#
#    postal_code            last_seen
# 0        79588  2016-04-06 06:45:54
# 1        71034  2016-04-06 14:45:08
# 2        35394  2016-04-06 20:15:37
# 3        33729  2016-03-15 03:16:28
# 4        39218  2016-04-01 14:38:50

# %% [markdown]
# I changed from camelCase to snake_case and modified the name of 4 columns to make them more descriptive.

# %% [markdown]
# ## 3.- Preliminary Data exploration.
#
# Use `DataFrame.describe()`, `Series.value_counts()` and `Series.head()` to explore data and determine what needs cleaning and what need to be dropped.

# %%
autos.describe(include='all')
# Out:
#                date_crawled         name  seller offer_type  price ab_test  \
# count                 50000        50000   50000      50000  50000   50000
# unique                48213        38754       2          2   2357       2
# top     2016-03-08 10:40:35  Ford_Fiesta  privat    Angebot     $0    test
# freq                      3           78   49999      49999   1421   25756
# mean                    NaN          NaN     NaN        NaN    NaN     NaN
# std                     NaN          NaN     NaN        NaN    NaN     NaN
# min                     NaN          NaN     NaN        NaN    NaN     NaN
# 25%                     NaN          NaN     NaN        NaN    NaN     NaN
# 50%                     NaN          NaN     NaN        NaN    NaN     NaN
# 75%                     NaN          NaN     NaN        NaN    NaN     NaN
# max                     NaN          NaN     NaN        NaN    NaN     NaN
#
#        vehicle_type  registration_year gear_box      power_PS  model  \
# count         44905       50000.000000    47320  50000.000000  47242
# unique            8                NaN        2           NaN    245
# top       limousine                NaN  manuell           NaN   golf
# freq          12859                NaN    36993           NaN   4024
# mean            NaN        2005.073280      NaN    116.355920    NaN
# std             NaN         105.712813      NaN    209.216627    NaN
# min             NaN        1000.000000      NaN      0.000000    NaN
# 25%             NaN        1999.000000      NaN     70.000000    NaN
# 50%             NaN        2003.000000      NaN    105.000000    NaN
# 75%             NaN        2008.000000      NaN    150.000000    NaN
# max             NaN        9999.000000      NaN  17700.000000    NaN
#
#          odometer  registration_month fuel_type       brand unrepaired_damage  \
# count       50000        50000.000000     45518       50000             40171
# unique         13                 NaN         7          40                 2
# top     150,000km                 NaN    benzin  volkswagen              nein
# freq        32424                 NaN     30107       10687             35232
# mean          NaN            5.723360       NaN         NaN               NaN
# std           NaN            3.711984       NaN         NaN               NaN
# min           NaN            0.000000       NaN         NaN               NaN
# 25%           NaN            3.000000       NaN         NaN               NaN
# 50%           NaN            6.000000       NaN         NaN               NaN
# 75%           NaN            9.000000       NaN         NaN               NaN
# max           NaN           12.000000       NaN         NaN               NaN
#
#                  ad_created  nr_of_pictures   postal_code            last_seen
# count                 50000         50000.0  50000.000000                50000
# unique                   76             NaN           NaN                39481
# top     2016-04-03 00:00:00             NaN           NaN  2016-04-07 06:17:27
# freq                   1946             NaN           NaN                    8
# mean                    NaN             0.0  50813.627300                  NaN
# std                     NaN             0.0  25779.747957                  NaN
# min                     NaN             0.0   1067.000000                  NaN
# 25%                     NaN             0.0  30451.000000                  NaN
# 50%                     NaN             0.0  49577.000000                  NaN
# 75%                     NaN             0.0  71540.000000                  NaN
# max                     NaN             0.0  99998.000000                  NaN

# %%
autos["seller"].value_counts()
# Out:
# privat        49999
# gewerblich        1
# Name: seller, dtype: int64

# %%
autos["offer_type"].value_counts()
# Out:
# Angebot    49999
# Gesuch         1
# Name: offer_type, dtype: int64

# %%
autos["nr_of_pictures"].value_counts()
# Out:
# 0    50000
# Name: nr_of_pictures, dtype: int64

# %% [markdown]
# Change column name "odometer" for "odometer_km".
#
# Erase the following columns: `seller`, `offer_type`, `nr_of_pictures`.
#
# Delete non-numeric values from `price` and `odometer`. Display as floats.

# %%
autos.rename(columns={"odometer":"odometer_km"}, inplace = True)
autos.drop(["seller", "offer_type", "nr_of_pictures"], axis = 1, inplace = True)
autos["price"] = autos["price"].str.replace("$","").str.replace(",","").astype(int)
autos["odometer_km"] = autos["odometer_km"].str.replace("km","").str.replace(",","").astype(int)
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    price  ab_test vehicle_type  registration_year   gear_box  power_PS  \
# 0   5000  control          bus               2004    manuell       158
# 1   8500  control    limousine               1997  automatik       286
# 2   8990     test    limousine               2009    manuell       102
# 3   4350  control   kleinwagen               2007  automatik        71
# 4   1350     test        kombi               2003    manuell         0
#
#     model  odometer_km  registration_month fuel_type       brand  \
# 0  andere       150000                   3       lpg     peugeot
# 1     7er       150000                   6    benzin         bmw
# 2    golf        70000                   7    benzin  volkswagen
# 3  fortwo        70000                   6    benzin       smart
# 4   focus       150000                   7    benzin        ford
#
#   unrepaired_damage           ad_created  postal_code            last_seen
# 0              nein  2016-03-26 00:00:00        79588  2016-04-06 06:45:54
# 1              nein  2016-04-04 00:00:00        71034  2016-04-06 14:45:08
# 2              nein  2016-03-26 00:00:00        35394  2016-04-06 20:15:37
# 3              nein  2016-03-12 00:00:00        33729  2016-03-15 03:16:28
# 4              nein  2016-04-01 00:00:00        39218  2016-04-01 14:38:50

# %% [markdown]
# ## 4.- Data Analysis for Price and Odometer.
#
# Use `Seriews.unique().shape`, `Series.describe()` and `Series.value_counts()` to explore data and determine if there's outliers that need to be dropped.

# %%
autos["price"].unique().shape
# Out:
# (2357,)

# %%
autos["price"].describe().apply(lambda x: format(x, 'f')) #Found this lambda to better view info.
# Out:
# count       50000.000000
# mean         9840.043760
# std        481104.380500
# min             0.000000
# 25%          1100.000000
# 50%          2950.000000
# 75%          7200.000000
# max      99999999.000000
# Name: price, dtype: object

# %%
autos["price"].value_counts().sort_index(ascending = True).head(20)
# Out:
# 0     1421
# 1      156
# 2        3
# 3        1
# 5        2
# 8        1
# 9        1
# 10       7
# 11       2
# 12       3
# 13       2
# 14       1
# 15       2
# 17       3
# 18       1
# 20       4
# 25       5
# 29       1
# 30       7
# 35       1
# Name: price, dtype: int64

# %%
autos["price"].value_counts().sort_index(ascending = False).head(20)
# Out:
# 99999999    1
# 27322222    1
# 12345678    3
# 11111111    2
# 10000000    1
# 3890000     1
# 1300000     1
# 1234566     1
# 999999      2
# 999990      1
# 350000      1
# 345000      1
# 299000      1
# 295000      1
# 265000      1
# 259000      1
# 250000      1
# 220000      1
# 198000      1
# 197000      1
# Name: price, dtype: int64

# %% [markdown]
# After review, I decided to drop values < than 1,000 because of the first quartile, up to 155,000 because from there up those cars just inflate the statistics.
#
# But after running the code, it seemed I was going to wipe out more than 20% of the data.
#
# I decided to wipe less than 10% of the data so instead of using 1,000 I droped to 200.

# %%
(~autos["price"].between(200,155000)).sum() / autos.shape[0] #In this code ~ invert operator selects 
                                                             #everything not between the two numbers
# Out:
# 0.04746

# %%
autos = autos[autos["price"].between(350,155000)]

# %%
autos["price"].describe().apply(lambda x: format(x, 'f'))
# Out:
# count     46395.000000
# mean       6067.411143
# std        8001.480566
# min         350.000000
# 25%        1400.000000
# 50%        3300.000000
# 75%        7750.000000
# max      155000.000000
# Name: price, dtype: object

# %%
autos["odometer_km"].unique().shape
# Out:
# (13,)

# %%
autos["odometer_km"].describe()
# Out:
# count     46395.000000
# mean     125674.964975
# std       39458.683760
# min        5000.000000
# 25%      100000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %%
autos["odometer_km"].value_counts()
# Out:
# 150000    29776
# 125000     4924
# 100000     2059
# 90000      1700
# 80000      1397
# 70000      1202
# 60000      1139
# 50000      1000
# 40000       809
# 30000       769
# 20000       729
# 5000        654
# 10000       237
# Name: odometer_km, dtype: int64

# %% [markdown]
# There is not much to change in odometer. The values seem to be predefined.

# %% [markdown]
# ## 5.- Data Analysis for Date Values.
#
# Use `Seriews.unique().shape`, `Series.describe()` and `Series.value_counts()` to explore date values data and understand distributions.

# %%
autos[['date_crawled','ad_created','last_seen']][0:5]
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50

# %% [markdown]
# According to the above list, data was created in a span of time since 2015 to 2016.

# %%
autos['last_seen'].str[:10].value_counts(normalize = True, dropna = False).sort_index()
# Out:
# 2016-03-05    0.001078
# 2016-03-06    0.004246
# 2016-03-07    0.005345
# 2016-03-08    0.007134
# 2016-03-09    0.009527
# 2016-03-10    0.010475
# 2016-03-11    0.012243
# 2016-03-12    0.023731
# 2016-03-13    0.008794
# 2016-03-14    0.012437
# 2016-03-15    0.015627
# 2016-03-16    0.016230
# 2016-03-17    0.027826
# 2016-03-18    0.007264
# 2016-03-19    0.015497
# 2016-03-20    0.020713
# 2016-03-21    0.020498
# 2016-03-22    0.021339
# 2016-03-23    0.018558
# 2016-03-24    0.019506
# 2016-03-25    0.018860
# 2016-03-26    0.016640
# 2016-03-27    0.015584
# 2016-03-28    0.020800
# 2016-03-29    0.021813
# 2016-03-30    0.024335
# 2016-03-31    0.023774
# 2016-04-01    0.022912
# 2016-04-02    0.024766
# 2016-04-03    0.025003
# 2016-04-04    0.024421
# 2016-04-05    0.126027
# 2016-04-06    0.223817
# 2016-04-07    0.133182
# Name: last_seen, dtype: float64

# %% [markdown]
# Data last viewed seems to indicate that ads were taken down sistematically. It's possible the car was sold or the listing expired. The last 3 days seems strange, there's not enough data to interpret what happened.

# %%
autos["registration_year"].describe()
# Out:
# count    46395.000000
# mean      2004.886259
# std         88.508813
# min       1000.000000
# 25%       1999.000000
# 50%       2004.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# According to this, it seems there was wrong data input. Let's filter these to 1985 to 2016 and see how much data need to be dropped.

# %%
(~autos["registration_year"].between(1970,2016)).sum() / autos.shape[0]
# Out:
# 0.04366849876064231

# %% [markdown]
# If we drop this percentage our erased data will be just over 10%, which for me is a good indicator.

# %%
autos = autos[autos["registration_year"].between(1970,2016)]
autos["registration_year"].describe()
# Out:
# count    44369.000000
# mean      2003.296806
# std          6.496227
# min       1970.000000
# 25%       1999.000000
# 50%       2003.000000
# 75%       2008.000000
# max       2016.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# ## 6.- Data Analysis for Car Brands.
#
# Use aggregation to explore date from Car Brands and Price.

# %%
autos["brand"].value_counts(normalize = True)
# Out:
# volkswagen        0.212085
# bmw               0.113458
# opel              0.103451
# mercedes_benz     0.099867
# audi              0.089612
# ford              0.066172
# renault           0.045460
# peugeot           0.029660
# fiat              0.024386
# seat              0.018233
# skoda             0.016859
# mazda             0.015236
# nissan            0.015101
# smart             0.014808
# citroen           0.014086
# toyota            0.013252
# hyundai           0.010210
# volvo             0.009173
# mini              0.009151
# sonstige_autos    0.008474
# mitsubishi        0.008001
# honda             0.007956
# kia               0.007325
# alfa_romeo        0.006761
# porsche           0.005928
# suzuki            0.005860
# chevrolet         0.005747
# chrysler          0.003584
# dacia             0.002772
# jeep              0.002389
# daihatsu          0.002299
# land_rover        0.002164
# subaru            0.002096
# saab              0.001645
# jaguar            0.001533
# daewoo            0.001330
# rover             0.001307
# lancia            0.001014
# trabant           0.000969
# lada              0.000586
# Name: brand, dtype: float64

# %% [markdown]
# Let's drop from our analysis all cars with less than 2% of representation.

# %%
brands = autos["brand"].value_counts(normalize = True)
represented_brands = brands[brands > .02].index
print(represented_brands)
# Out:
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford', 'renault',
#        'peugeot', 'fiat'],
#       dtype='object')

# %% [markdown]
# Now let's analyze price means for these cars.

# %%
price_mean_by_brand = {}

for b in represented_brands:
    selected_rows = autos[autos["brand"] == b]
    mean = selected_rows["price"].mean()
    price_mean_by_brand[b] = int(mean)

price_mean_by_brand
# Out:
# {'audi': 9435,
#  'bmw': 8354,
#  'fiat': 3039,
#  'ford': 3804,
#  'mercedes_benz': 8519,
#  'opel': 3221,
#  'peugeot': 3254,
#  'renault': 2673,
#  'volkswagen': 5632}

# %% [markdown]
# German cars tend to sell for more, as Audi, BMW, Mercedes Benz and Volkswagen are in the top positions.

# %%
pmbb_series = pd.Series(price_mean_by_brand)
pmbb_series
# Out:
# audi             9435
# bmw              8354
# fiat             3039
# ford             3804
# mercedes_benz    8519
# opel             3221
# peugeot          3254
# renault          2673
# volkswagen       5632
# dtype: int64

# %%
mileage_mean_by_brand = {}

for b in represented_brands:
    selected_rows = autos[autos["brand"] == b]
    mean = selected_rows["odometer_km"].mean()
    mileage_mean_by_brand[b] = int(mean)

mileage_mean_by_brand
# Out:
# {'audi': 129149,
#  'bmw': 133049,
#  'fiat': 116326,
#  'ford': 124409,
#  'mercedes_benz': 131380,
#  'opel': 128955,
#  'peugeot': 126618,
#  'renault': 127471,
#  'volkswagen': 128516}

# %%
mmbb_series = pd.Series(mileage_mean_by_brand)
mmbb_series
# Out:
# audi             129149
# bmw              133049
# fiat             116326
# ford             124409
# mercedes_benz    131380
# opel             128955
# peugeot          126618
# renault          127471
# volkswagen       128516
# dtype: int64

# %%
mean_database = pd.DataFrame(mmbb_series, columns=['mean_mileage'])
mean_database
# Out:
#                mean_mileage
# audi                 129149
# bmw                  133049
# fiat                 116326
# ford                 124409
# mercedes_benz        131380
# opel                 128955
# peugeot              126618
# renault              127471
# volkswagen           128516

# %%
mean_database["mean_price"] = pmbb_series
mean_database
# Out:
#                mean_mileage  mean_price
# audi                 129149        9435
# bmw                  133049        8354
# fiat                 116326        3039
# ford                 124409        3804
# mercedes_benz        131380        8519
# opel                 128955        3221
# peugeot              126618        3254
# renault              127471        2673
# volkswagen           128516        5632

# %% [markdown]
# With pandas series constructor and pandas dataframe constructor, I was able to convert a dictionary into a Series object, and then convert the Series object into a Dataframe object. Since pandas knows how to arrange by index, the data gets accurately positioned.

# %% [markdown]
# ## 7.- Data Cleaning.
# Now I will change the deutsch words for english, convert dates from strings to integers and extract, if any, information from the name column.

# %%
autos["vehicle_type"].unique()
# Out:
# array(['bus', 'limousine', 'kleinwagen', 'kombi', nan, 'coupe', 'suv',
#        'cabrio', 'andere'], dtype=object)

# %% [markdown]
# There's some data marked as nan. I will change that to not_specified and see if from name column can extract vehicle type.

# %%
vehicle_type_dict = {"bus": "bus",
                     "limousine": "limousine",
                     "kleinwagen": "small_car", 
                     "kombi": "station wagon",
                     "copue": "coupe",
                     "suv": "suv", 
                     "cabrio": "convertible",
                     "andere": "other"}
autos["vehicle_type"].replace(vehicle_type_dict,inplace=True)
autos["vehicle_type"].fillna("not_specified", inplace=True)

# %%
autos["gear_box"].unique()
# Out:
# array(['manuell', 'automatik', nan], dtype=object)

# %%
gear_box_dict = {"manuell": "manual", "automatik": "automatic"}
autos["gear_box"].replace(gear_box_dict,inplace=True)
autos["gear_box"].fillna("not_specified", inplace=True)

# %%
autos["fuel_type"].unique()
# Out:
# array(['lpg', 'benzin', 'diesel', nan, 'cng', 'hybrid', 'elektro',
#        'andere'], dtype=object)

# %%
fuel_type_dict = {"lpg": "lp_gas", "benzin": "gasoline", "cng": "natural_gas",
                  "hybrid": "hybrid", "elektro": "electric", "andere": "other"}
autos["fuel_type"].replace(fuel_type_dict,inplace=True)
autos["fuel_type"].fillna("not_specified", inplace=True)

# %%
autos["unrepaired_damage"].unique()
# Out:
# array(['nein', nan, 'ja'], dtype=object)

# %%
unrepaired_damage_dict = {"nein": "no", "ja": "yes"}
autos["unrepaired_damage"].replace(unrepaired_damage_dict,inplace=True)
autos["unrepaired_damage"].fillna("not_specified", inplace=True)

# %%
autos
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 11     2016-03-16 18:45:34                         Mercedes_A140_Motorschaden
# 12     2016-03-31 19:48:22  Smart_smart_fortwo_coupe_softouch_pure_MHD_Pan...
# 13     2016-03-23 10:48:32                                 Audi_A3_1.6_tuning
# 14     2016-03-23 11:50:46  Renault_Clio_3__Dynamique_1.2__16_V;_viele_Ver...
# 15     2016-04-01 12:06:20        Corvette_C3_Coupe_T_Top_Crossfire_Injection
# 16     2016-03-16 14:59:02                                Opel_Vectra_B_Kombi
# 17     2016-03-29 11:46:22                          Volkswagen_Scirocco_2_G60
# 19     2016-03-17 13:36:21        mazda_tribute_2.0_mit_gas_und_tuev_neu_2018
# 20     2016-03-05 19:57:31  Audi_A4_Avant_1.9_TDI_*6_Gang*AHK*Klimatronik*...
# 21     2016-03-06 19:07:10                      Porsche_911_Carrera_4S_Cabrio
# 22     2016-03-28 20:50:54                               MINI_Cooper_S_Cabrio
# 23     2016-03-10 19:55:34   Peugeot_Boxer_2_2_HDi_120_Ps_9_Sitzer_inkl_Klima
# 24     2016-04-03 11:57:02                         BMW_535i_xDrive_Sport_Aut.
# 26     2016-04-03 22:46:28                                Volkswagen_Polo_Fox
# 28     2016-03-19 21:56:19                                      MINI_Cooper_D
# 29     2016-04-02 12:45:44  Mercedes_Benz_E_320_T_CDI_Avantgarde_DPF7_Sitz...
# 31     2016-03-14 16:53:09                          Noch_gut_erhaltenen_C_320
# 32     2016-03-20 05:03:03                               Corsa_mit_TÜV_5.2016
# 33     2016-03-15 12:25:26  Audi_A3_2.0_TDI_Sportback_DPF_Kupplung_defekt_...
# 34     2016-04-05 07:55:07                            Bmw_530d__navi_tuv03/18
# 35     2016-03-29 21:52:56                                        Ford_Mondeo
# 36     2016-03-16 23:46:31          Ford_Mondeo_2.0_Turnier_TDCi_DPF_Titanium
# ...                    ...                                                ...
# 49967  2016-03-12 11:50:17                      VW_Passat_2_0_TDI_comfortline
# 49968  2016-04-01 17:49:15                  Mercedes_Benz_190_D_2.5_Automatik
# 49969  2016-03-17 18:49:02             Nissan_X_Trail_2.2_dCi_4x4_Sport_m.AHZ
# 49970  2016-03-21 22:47:37  c4_Grand_Picasso_mit_Automatik_Leder_Navi_Temp...
# 49971  2016-03-29 14:54:12                                         W.Lupo_1.0
# 49972  2016-03-26 22:25:23          Mercedes_Benz_Vito_115_CDI_Extralang_Aut.
# 49973  2016-03-27 05:32:39                   Mercedes_Benz_SLK_200_Kompressor
# 49975  2016-03-27 20:51:39          Honda_Jazz_1.3_DSi_i_VTEC_IMA_CVT_Comfort
# 49976  2016-03-19 18:56:05  Audi_80_Avant_2.6_E__Vollausstattung!!_Einziga...
# 49977  2016-03-31 18:37:18                        Mercedes_Benz_C200_Cdi_W203
# 49978  2016-04-04 10:37:14                        Mercedes_Benz_E_200_Classic
# 49979  2016-03-20 18:38:40                      Volkswagen_Polo_1.6_TDI_Style
# 49980  2016-03-12 10:55:54                            Ford_Escort_Turnier_16V
# 49981  2016-03-15 09:38:21             Opel_Astra_Kombi_mit_Anhaengerkupplung
# 49982  2016-03-29 18:51:08            Skoda_Fabia_4_Tuerer_Bj:2004__85.000Tkm
# 49983  2016-03-06 12:43:04                                      Ford_focus_99
# 49985  2016-04-02 16:38:23                          Verkaufe_meinen_vw_vento!
# 49986  2016-04-04 20:46:02  Chrysler_300C_3.0_CRD_DPF_Automatik_Voll_Ausst...
# 49987  2016-03-22 20:47:27  Audi_A3_Limousine_2.0_TDI_DPF_Ambition__NAVI__...
# 49988  2016-03-28 19:49:51                                         BMW_330_Ci
# 49990  2016-03-21 19:54:19         Mercedes_Benz_A_200__BlueEFFICIENCY__Urban
# 49991  2016-03-06 15:25:19                                         Kleinwagen
# 49992  2016-03-10 19:37:38              Fiat_Grande_Punto_1.4_T_Jet_16V_Sport
# 49993  2016-03-15 18:47:35           Audi_A3__1_8l__Silber;_schoenes_Fahrzeug
# 49994  2016-03-22 17:36:42  Audi_A6__S6__Avant_4.2_quattro_eventuell_Tausc...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
#        price  ab_test   vehicle_type  registration_year       gear_box  \
# 0       5000  control            bus               2004         manual
# 1       8500  control      limousine               1997      automatic
# 2       8990     test      limousine               2009         manual
# 3       4350  control      small_car               2007      automatic
# 4       1350     test  station wagon               2003         manual
# 5       7900     test            bus               2006      automatic
# 7       1990  control      limousine               1998         manual
# 9        590  control            bus               1997         manual
# 11       350  control  not_specified               2000  not_specified
# 12      5299  control      small_car               2010      automatic
# 13      1350  control      limousine               1999         manual
# 14      3999     test      small_car               2007         manual
# 15     18900     test          coupe               1982      automatic
# 16       350     test  station wagon               1999         manual
# 17      5500     test          coupe               1990         manual
# 19      4150  control            suv               2004         manual
# 20      3500     test  station wagon               2003         manual
# 21     41500     test    convertible               2004         manual
# 22     25450  control    convertible               2015         manual
# 23      7999  control            bus               2010         manual
# 24     48500  control      limousine               2014      automatic
# 26       777  control      small_car               1992         manual
# 28      5250  control      small_car               2007         manual
# 29      4999     test  station wagon               2004      automatic
# 31      2850     test  station wagon               2002      automatic
# 32       350  control      small_car               1999         manual
# 33      4800     test  station wagon               2006         manual
# 34      2600     test  station wagon               2000      automatic
# 35      1200     test  station wagon               1998         manual
# 36      7500     test  station wagon               2007         manual
# ...      ...      ...            ...                ...            ...
# 49967   4999     test  station wagon               2006         manual
# 49968   2100     test      limousine               1986      automatic
# 49969   4500  control            suv               2005         manual
# 49970  15800  control            bus               2010      automatic
# 49971    950     test      small_car               2001         manual
# 49972   3300  control            bus               2004      automatic
# 49973   6000  control    convertible               2004         manual
# 49975   9700  control      small_car               2012      automatic
# 49976   5900     test  station wagon               1992      automatic
# 49977   5500  control      limousine               2003         manual
# 49978    900  control      limousine               1996      automatic
# 49979  11000     test      small_car               2011         manual
# 49980    400  control  station wagon               1995         manual
# 49981   2000  control  station wagon               1998         manual
# 49982   1950  control      small_car               2004         manual
# 49983    600     test      small_car               1999         manual
# 49985   1000  control  not_specified               1995      automatic
# 49986  15900  control      limousine               2010      automatic
# 49987  21990  control      limousine               2013         manual
# 49988   9550  control          coupe               2001         manual
# 49990  17500     test      limousine               2012         manual
# 49991    500  control  not_specified               2016         manual
# 49992   4800  control      small_car               2009         manual
# 49993   1650  control      small_car               1997         manual
# 49994   5000  control  station wagon               2001      automatic
# 49995  24900  control      limousine               2011      automatic
# 49996   1980  control    convertible               1996         manual
# 49997  13200     test    convertible               2014      automatic
# 49998  22900  control  station wagon               2013         manual
# 49999   1250  control      limousine               1996         manual
#
#        power_PS     model  odometer_km  registration_month fuel_type  \
# 0           158    andere       150000                   3    lp_gas
# 1           286       7er       150000                   6  gasoline
# 2           102      golf        70000                   7  gasoline
# 3            71    fortwo        70000                   6  gasoline
# 4             0     focus       150000                   7  gasoline
# 5           150   voyager       150000                   4    diesel
# 7            90      golf       150000                  12    diesel
# 9            90    megane       150000                   7  gasoline
# 11            0       NaN       150000                   0  gasoline
# 12           71    fortwo        50000                   9  gasoline
# 13          101        a3       150000                  11  gasoline
# 14           75      clio       150000                   9  gasoline
# 15          203       NaN        80000                   6  gasoline
# 16          101    vectra       150000                   5  gasoline
# 17          205  scirocco       150000                   6  gasoline
# 19          124    andere       150000                   2    lp_gas
# 20          131        a4       150000                   5    diesel
# 21          320       911       150000                   4  gasoline
# 22          184    cooper        10000                   1  gasoline
# 23          120       NaN       150000                   2    diesel
# 24          306       5er        30000                  12  gasoline
# 26           54      polo       125000                   2  gasoline
# 28          110    cooper       150000                   7    diesel
# 29          204  e_klasse       150000                  10    diesel
# 31          218  c_klasse       150000                   7  gasoline
# 32            0     corsa       150000                   7  gasoline
# 33          140        a3       150000                   8    diesel
# 34          193       5er       150000                   6    diesel
# 35            0    mondeo       150000                  12  gasoline
# 36          131    mondeo       150000                  11    diesel
# ...         ...       ...          ...                 ...       ...
# 49967       140    passat       150000                   5    diesel
# 49968        90    andere       150000                   9    diesel
# 49969       136   x_trail       150000                   5    diesel
# 49970       136        c4        60000                   4    diesel
# 49971        50      lupo       150000                   4  gasoline
# 49972       150      vito       150000                  10    diesel
# 49973       163       slk       150000                  11  gasoline
# 49975        88      jazz       100000                  11    hybrid
# 49976       150        80       150000                  12  gasoline
# 49977       116  c_klasse       150000                   2    diesel
# 49978       136  e_klasse       150000                   9  gasoline
# 49979        90      polo        70000                  11    diesel
# 49980       105    escort       125000                   3  gasoline
# 49981       115     astra       150000                  12  gasoline
# 49982         0     fabia        90000                   7  gasoline
# 49983       101     focus       150000                   4  gasoline
# 49985         0       NaN       150000                   0  gasoline
# 49986       218      300c       125000                  11    diesel
# 49987       150        a3        50000                  11    diesel
# 49988       231       3er       150000                  10  gasoline
# 49990       156  a_klasse        30000                  12  gasoline
# 49991         0    twingo       150000                   0  gasoline
# 49992       120    andere       125000                   9    lp_gas
# 49993         0       NaN       150000                   7  gasoline
# 49994       299        a6       150000                   1  gasoline
# 49995       239        q5       100000                   1    diesel
# 49996        75     astra       150000                   5  gasoline
# 49997        69       500         5000                  11  gasoline
# 49998       150        a3        40000                  11    diesel
# 49999       101    vectra       150000                   1  gasoline
#
Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...   1350
# 5          20160321  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...   7900
# 7          20160316                               Golf_IV_1.9_TDI_90PS   1990
# 9          20160316          Renault_Megane_Scenic_1.6e_RT_Klimaanlage    590
# 11         20160316                         Mercedes_A140_Motorschaden    350
# 12         20160331  Smart_smart_fortwo_coupe_softouch_pure_MHD_Pan...   5299
# 13         20160323                                 Audi_A3_1.6_tuning   1350
# 14         20160323  Renault_Clio_3__Dynamique_1.2__16_V;_viele_Ver...   3999
# 15         20160401        Corvette_C3_Coupe_T_Top_Crossfire_Injection  18900
# 16         20160316                                Opel_Vectra_B_Kombi    350
# 17         20160329                          Volkswagen_Scirocco_2_G60   5500
# 19         20160317        mazda_tribute_2.0_mit_gas_und_tuev_neu_2018   4150
# 20         20160305  Audi_A4_Avant_1.9_TDI_*6_Gang*AHK*Klimatronik*...   3500
# 21         20160306                      Porsche_911_Carrera_4S_Cabrio  41500
# 22         20160328                               MINI_Cooper_S_Cabrio  25450
# 23         20160310   Peugeot_Boxer_2_2_HDi_120_Ps_9_Sitzer_inkl_Klima   7999
# 24         20160403                         BMW_535i_xDrive_Sport_Aut.  48500
# 26         20160403                                Volkswagen_Polo_Fox    777
# 28         20160319                                      MINI_Cooper_D   5250
# 29         20160402  Mercedes_Benz_E_320_T_CDI_Avantgarde_DPF7_Sitz...   4999
# 31         20160314                          Noch_gut_erhaltenen_C_320   2850
# 32         20160320                               Corsa_mit_TÜV_5.2016    350
# 33         20160315  Audi_A3_2.0_TDI_Sportback_DPF_Kupplung_defekt_...   4800
# 34         20160405                            Bmw_530d__navi_tuv03/18   2600
# 35         20160329                                        Ford_Mondeo   1200
# 36         20160316          Ford_Mondeo_2.0_Turnier_TDCi_DPF_Titanium   7500
# ...             ...                                                ...    ...
# 49967      20160312                      VW_Passat_2_0_TDI_comfortline   4999
# 49968      20160401                  Mercedes_Benz_190_D_2.5_Automatik   2100
# 49969      20160317             Nissan_X_Trail_2.2_dCi_4x4_Sport_m.AHZ   4500
# 49970      20160321  c4_Grand_Picasso_mit_Automatik_Leder_Navi_Temp...  15800
# 49971      20160329                                         W.Lupo_1.0    950
# 49972      20160326          Mercedes_Benz_Vito_115_CDI_Extralang_Aut.   3300
# 49973      20160327                   Mercedes_Benz_SLK_200_Kompressor   6000
# 49975      20160327          Honda_Jazz_1.3_DSi_i_VTEC_IMA_CVT_Comfort   9700
# 49976      20160319  Audi_80_Avant_2.6_E__Vollausstattung!!_Einziga...   5900
# 49977      20160331                        Mercedes_Benz_C200_Cdi_W203   5500
# 49978      20160404                        Mercedes_Benz_E_200_Classic    900
# 49979      20160320                      Volkswagen_Polo_1.6_TDI_Style  11000
# 49980      20160312                            Ford_Escort_Turnier_16V    400
# 49981      20160315             Opel_Astra_Kombi_mit_Anhaengerkupplung   2000
# 49982      20160329            Skoda_Fabia_4_Tuerer_Bj:2004__85.000Tkm   1950
# 49983      20160306                                      Ford_focus_99    600
# 49985      20160402                          Verkaufe_meinen_vw_vento!   1000
# 49986      20160404  Chrysler_300C_3.0_CRD_DPF_Automatik_Voll_Ausst...  15900
# 49987      20160322  Audi_A3_Limousine_2.0_TDI_DPF_Ambition__NAVI__...  21990
# 49988      20160328                                         BMW_330_Ci   9550
# 49990      20160321         Mercedes_Benz_A_200__BlueEFFICIENCY__Urban  17500
# 49991      20160306                                         Kleinwagen    500
# 49992      20160310              Fiat_Grande_Punto_1.4_T_Jet_16V_Sport   4800
# 49993      20160315           Audi_A3__1_8l__Silber;_schoenes_Fahrzeug   1650
# 49994      20160322  Audi_A6__S6__Avant_4.2_quattro_eventuell_Tausc...   5000
# 49995      20160327   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon  24900
# 49996      20160328  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...   1980
# 49997      20160402                     Fiat_500_C_1.2_Dualogic_Lounge  13200
# 49998      20160308                 Audi_A3_2.0_TDI_Sportback_Ambition  22900
# 49999      20160314                                Opel_Vectra_1.6_16V   1250
#
#        ab_test   vehicle_type  registration_year       gear_box  power_PS  \
# 0      control            bus               2004         manual       158
# 1      control      limousine               1997      automatic       286
# 2         test      limousine               2009         manual       102
# 3      control      small_car               2007      automatic        71
# 4         test  station wagon               2003         manual         0
# 5         test            bus               2006      automatic       150
# 7      control      limousine               1998         manual        90
# 9      control            bus               1997         manual        90
# 11     control  not_specified               2000  not_specified         0
# 12     control      small_car               2010      automatic        71
# 13     control      limousine               1999         manual       101
# 14        test      small_car               2007         manual        75
# 15        test          coupe               1982      automatic       203
# 16        test  station wagon               1999         manual       101
# 17        test          coupe               1990         manual       205
# 19     control            suv               2004         manual       124
# 20        test  station wagon               2003         manual       131
# 21        test    convertible               2004         manual       320
# 22     control    convertible               2015         manual       184
# 23     control            bus               2010         manual       120
# 24     control      limousine               2014      automatic       306
# 26     control      small_car               1992         manual        54
# 28     control      small_car               2007         manual       110
# 29        test  station wagon               2004      automatic       204
# 31        test  station wagon               2002      automatic       218
# 32     control      small_car               1999         manual         0
# 33        test  station wagon               2006         manual       140
# 34        test  station wagon               2000      automatic       193
# 35        test  station wagon               1998         manual         0
# 36        test  station wagon               2007         manual       131
# ...        ...            ...                ...            ...       ...
# 49967     test  station wagon               2006         manual       140
# 49968     test      limousine               1986      automatic        90
# 49969  control            suv               2005         manual       136
# 49970  control            bus               2010      automatic       136
# 49971     test      small_car               2001         manual        50
# 49972  control            bus               2004      automatic       150
# 49973  control    convertible               2004         manual       163
# 49975  control      small_car               2012      automatic        88
# 49976     test  station wagon               1992      automatic       150
# 49977  control      limousine               2003         manual       116
# 49978  control      limousine               1996      automatic       136
# 49979     test      small_car               2011         manual        90
# 49980  control  station wagon               1995         manual       105
# 49981  control  station wagon               1998         manual       115
# 49982  control      small_car               2004         manual         0
# 49983     test      small_car               1999         manual       101
# 49985  control  not_specified               1995      automatic         0
# 49986  control      limousine               2010      automatic       218
# 49987  control      limousine               2013         manual       150
# 49988  control          coupe               2001         manual       231
# 49990     test      limousine               2012         manual       156
# 49991  control  not_specified               2016         manual         0
# 49992  control      small_car               2009         manual       120
# 49993  control      small_car               1997         manual         0
# 49994  control  station wagon               2001      automatic       299
# 49995  control      limousine               2011      automatic       239
# 49996  control    convertible               1996         manual        75
# 49997     test    convertible               2014      automatic        69
# 49998  control  station wagon               2013         manual       150
# 49999  control      limousine               1996         manual       101
#
#           model  odometer_km  registration_month fuel_type           brand  \
# 0        andere       150000                   3    lp_gas         peugeot
# 1           7er       150000                   6  gasoline             bmw
# 2          golf        70000                   7  gasoline      volkswagen
# 3        fortwo        70000                   6  gasoline           smart
# 4         focus       150000                   7  gasoline            ford
# 5       voyager       150000                   4    diesel        chrysler
# 7          golf       150000                  12    diesel      volkswagen
# 9        megane       150000                   7  gasoline         renault
# 11          NaN       150000                   0  gasoline   mercedes_benz
# 12       fortwo        50000                   9  gasoline           smart
# 13           a3       150000                  11  gasoline            audi
# 14         clio       150000                   9  gasoline         renault
# 15          NaN        80000                   6  gasoline  sonstige_autos
# 16       vectra       150000                   5  gasoline            opel
# 17     scirocco       150000                   6  gasoline      volkswagen
# 19       andere       150000                   2    lp_gas           mazda
# 20           a4       150000                   5    diesel            audi
# 21          911       150000                   4  gasoline         porsche
# 22       cooper        10000                   1  gasoline            mini
# 23          NaN       150000                   2    diesel         peugeot
# ...                 ...         ...          ...        ...
# 49967     not_specified    20160312        70619   20160317
# 49968                no    20160401        40227   20160405
# 49969                no    20160317        17379   20160325
# 49970                no    20160321        14947   20160407
# 49971                no    20160329        65197   20160329
# 49972               yes    20160326        65326   20160328
# 49973                no    20160327        53567   20160327
# 49975                no    20160327        84385   20160405
# 49976                no    20160319        36100   20160407
# 49977                no    20160331        33739   20160406
# 49978               yes    20160404        24405   20160406
# 49979                no    20160320        48455   20160407
# 49980     not_specified    20160312        56218   20160406
# 49981                no    20160315        86859   20160405
# 49982     not_specified    20160329        45884   20160329
# 49983     not_specified    20160306        52477   20160309
# 49985     not_specified    20160402        30900   20160406
# 49986                no    20160404        73527   20160406
# 49987                no    20160322        94362   20160326
# 49988                no    20160328        83646   20160407
# 49990                no    20160321        58239   20160406
# 49991     not_specified    20160306        61350   20160306
# 49992                no    20160310        68642   20160313
# 49993     not_specified    20160315        65203   20160406
# 49994                no    20160322        46537   20160406
# 49995                no    20160327        82131   20160401
# 49996                no    20160328        44807   20160402
# 49997                no    20160402        73430   20160404
# 49998                no    20160308        35683   20160405
# 49999                no    20160313        45897   20160406
#
# [44369 rows x 17 columns]

# %% [markdown]
# Now to check on the name column.

# %%
name_dataframe = pd.DataFrame(autos["name"].str.split("_", expand = True))
name_dataframe
# Out:
#                0         1             2        3   \
# 0         Peugeot       807           160  NAVTECH
# 1             BMW      740i             4        4
# 2      Volkswagen      Golf           1.6   United
# 3           Smart     smart        fortwo    coupe
# 4            Ford     Focus             1        6
# 5        Chrysler     Grand       Voyager      2.8
# 7            Golf        IV           1.9      TDI
# 9         Renault    Megane        Scenic     1.6e
# 11       Mercedes      A140  Motorschaden     None
# 12          Smart     smart        fortwo    coupe
# 13           Audi        A3           1.6   tuning
# 14        Renault      Clio             3
# 15       Corvette        C3         Coupe        T
# 16           Opel    Vectra             B    Kombi
# 17     Volkswagen  Scirocco             2      G60
# 19          mazda   tribute           2.0      mit
# 20           Audi        A4         Avant      1.9
# 21        Porsche       911       Carrera       4S
# 22           MINI    Cooper             S   Cabrio
# 23        Peugeot     Boxer             2        2
# 24            BMW      535i        xDrive    Sport
# 26     Volkswagen      Polo           Fox     None
# 28           MINI    Cooper             D     None
# 29       Mercedes      Benz             E      320
# 31           Noch       gut    erhaltenen        C
# 32          Corsa       mit           TÜV   5.2016
# 33           Audi        A3           2.0      TDI
# 34            Bmw      530d                   navi
# 35           Ford    Mondeo          None     None
# 36           Ford    Mondeo           2.0  Turnier
# ...           ...       ...           ...      ...
# 49967          VW    Passat             2        0
# 49968    Mercedes      Benz           190        D
# 49969      Nissan         X         Trail      2.2
# 49970          c4     Grand       Picasso      mit
# 49971      W.Lupo       1.0          None     None
# 49972    Mercedes      Benz          Vito      115
# 49973    Mercedes      Benz           SLK      200
# 49975       Honda      Jazz           1.3      DSi
# 49976        Audi        80         Avant      2.6
# 49977    Mercedes      Benz          C200      Cdi
# 49978    Mercedes      Benz             E      200
# 49979  Volkswagen      Polo           1.6      TDI
# 49980        Ford    Escort       Turnier      16V
# 49981        Opel     Astra         Kombi      mit
# 49982       Skoda     Fabia             4   Tuerer
# 49983        Ford     focus            99     None
# 49985    Verkaufe    meinen            vw   vento!
# 49986    Chrysler      300C           3.0      CRD
# 49987        Audi        A3     Limousine      2.0
# 49988         BMW       330            Ci     None
# 49990    Mercedes      Benz             A      200
# 49991  Kleinwagen      None          None     None
# 49992        Fiat    Grande         Punto      1.4
# 49993        Audi        A3                      1
# 49994        Audi        A6                     S6
# 49995        Audi        Q5           3.0      TDI
# 49996        Opel     Astra             F   Cabrio
# 49997        Fiat       500             C      1.2
# 49998        Audi        A3           2.0      TDI
# 49999        Opel    Vectra           1.6      16V
#
#                                4               5   \
# 0                              ON           BOARD
# 1                           Liter          HAMANN
# 2                            None            None
# 3      softouch/F1/Klima/Panorama            None
# 4                          Benzin             TÜV
# 5                             CRD     Aut.Limited
# 7                            90PS            None
# 9                              RT     Klimaanlage
# 11                           None            None
# 12                       softouch            pure
# 13                           None            None
# 14                      Dynamique             1.2
# 15                            Top       Crossfire
# 16                           None            None
# 17                           None            None
# 19                            gas             und
# 20                            TDI              *6
# 21                         Cabrio            None
# 22                           None            None
# 23                            HDi             120
# 24                           Aut.            None
# 26                           None            None
# 28                           None            None
# 29                              T             CDI
# 31                            320            None
# 32                           None            None
# 33                      Sportback             DPF
# 34                       tuv03/18            None
# 35                           None            None
# 36                           TDCi             DPF
# ...                           ...             ...
# 49967                         TDI     comfortline
# 49968                         2.5       Automatik
# 49969                         dCi             4x4
# 49970                   Automatik           Leder
# 49971                        None            None
# 49972                         CDI       Extralang
# 49973                  Kompressor            None
# 49975                           i            VTEC
# 49976                           E
# 49977                        W203            None
# 49978                     Classic            None
# 49979                       Style            None
# 49980                        None            None
# 49981           Anhaengerkupplung            None
# 49982                     Bj:2004
# 49983                        None            None
# 49985                        None            None
# 49986                         DPF       Automatik
# 49987                         TDI             DPF
# 49988                        None            None
# 49990                              BlueEFFICIENCY
# 49991                        None            None
# 49992                           T             Jet
# 49993                          8l
# 49994                                       Avant
# 49995                         qu.               S
# 49996                     Bertone         Edition
# 49997                    Dualogic          Lounge
# 49998                   Sportback        Ambition
# 49999                        None            None
#
#                                       6               7          8   \
# 0                                   None            None       None
# 1                                  UMBAU            Mega      Optik
# 2                                   None            None       None
# 3                                   None            None       None
# 4                                    neu             ist       sehr
# 5                                 Stow´n              Go      Sitze
# 7                                   None            None       None
# 9                                   None            None       None
# 11                                  None            None       None
# 12                                   MHD    Panoramadach
# 13                                  None            None       None
# 14                                                    16         V;
# 15                             Injection            None       None
# 16                                  None            None       None
# 17                                  None            None       None
# 19                                  tuev             neu       2018
# 20     Gang*AHK*Klimatronik*DPF*AGR*TÜV*            None       None
# 21                                  None            None       None
# 22                                  None            None       None
# 23                                    Ps               9     Sitzer
# 24                                  None            None       None
# 26                                  None            None       None
# 28                                  None            None       None
# 29                            Avantgarde            DPF7      Sitze
# 31                                  None            None       None
# 32                                  None            None       None
# 33                              Kupplung          defekt    fahrber
# 34                                  None            None       None
# 35                                  None            None       None
# 49978          None  ...   None  None  None  None  None  None  None  None
# 49979          None  ...   None  None  None  None  None  None  None  None
# 49980          None  ...   None  None  None  None  None  None  None  None
# 49981          None  ...   None  None  None  None  None  None  None  None
# 49982          None  ...   None  None  None  None  None  None  None  None
# 49983          None  ...   None  None  None  None  None  None  None  None
# 49985          None  ...   None  None  None  None  None  None  None  None
# 49986          None  ...   None  None  None  None  None  None  None  None
# 49987                ...   None  None  None  None  None  None  None  None
# 49988          None  ...   None  None  None  None  None  None  None  None
# 49990          None  ...   None  None  None  None  None  None  None  None
# 49991          None  ...   None  None  None  None  None  None  None  None
# 49992          None  ...   None  None  None  None  None  None  None  None
# 49993          None  ...   None  None  None  None  None  None  None  None
# 49994        Tausch  ...   None  None  None  None  None  None  None  None
# 49995                ...   None  None  None  None  None  None  None  None
# 49996    neu+Reifen  ...   None  None  None  None  None  None  None  None
# 49997          None  ...   None  None  None  None  None  None  None  None
# 49998          None  ...   None  None  None  None  None  None  None  None
# 49999          None  ...   None  None  None  None  None  None  None  None
#
#          25    26
# 0      None  None
# 1      None  None
# 2      None  None
# 3      None  None
# 4      None  None
# 5      None  None
# 7      None  None
# 9      None  None
# 11     None  None
# 12     None  None
# 13     None  None
# 14     None  None
# 15     None  None
# 16     None  None
# 17     None  None
# 19     None  None
# 20     None  None
# 21     None  None
# 22     None  None
# 23     None  None
# 24     None  None
# 26     None  None
# 28     None  None
# 29     None  None
# 31     None  None
# 32     None  None
# 33     None  None
# 34     None  None
# 35     None  None
# 36     None  None
# ...     ...   ...
# 49967  None  None
# 49968  None  None
# 49969  None  None
# 49970  None  None
# 49971  None  None
# 49972  None  None
# 49973  None  None
# 49975  None  None
# 49976  None  None
# 49977  None  None
# 49978  None  None
# 49979  None  None
# 49980  None  None
# 49981  None  None
# 49982  None  None
# 49983  None  None
# 49985  None  None
# 49986  None  None
# 49987  None  None
# 49988  None  None
# 49990  None  None
# 49991  None  None
# 49992  None  None
# 49993  None  None
# 49994  None  None
# 49995  None  None
# 49996  None  None
# 49997  None  None
# 49998  None  None
# 49999  None  None
#
# [44369 rows x 27 columns]

# %% [markdown]
# I may be able to extract data on the engine from this, but I decided against it to avoid scope creep.

# %% [markdown]
# ## 8.- Data Analysis.
# Now I will find the most common brand/model combinations, split odometer_km into groups and analyze average prices per group and lastly determine how much cheaper cars with damage are than their non-damaged peers.

# %%
autos["model_brand"] = autos["model"] + " " + autos["brand"]
autos["model_brand"].head()
# Out:
# 0     andere peugeot
# 1            7er bmw
# 2    golf volkswagen
# 3       fortwo smart
# 4         focus ford
# Name: model_brand, dtype: object

# %%
autos["model_brand"].value_counts(normalize = True).head(20)
# Out:
# golf volkswagen           0.083455
# 3er bmw                   0.060249
# polo volkswagen           0.033584
# corsa opel                0.032502
# passat volkswagen         0.031349
# astra opel                0.030078
# a4 audi                   0.028571
# c_klasse mercedes_benz    0.026665
# 5er bmw                   0.026430
# e_klasse mercedes_benz    0.022358
# a3 audi                   0.019369
# a6 audi                   0.018640
# focus ford                0.017298
# transporter volkswagen    0.015768
# fiesta ford               0.015180
# 2_reihe peugeot           0.013862
# fortwo smart              0.012874
# twingo renault            0.012591
# a_klasse mercedes_benz    0.012568
# 1er bmw                   0.012120
# Name: model_brand, dtype: float64

# %%
models = autos["model_brand"].value_counts(normalize = True)
represented_models = models[models > .02].index
print(represented_models)
# Out:
# Index(['golf volkswagen', '3er bmw', 'polo volkswagen', 'corsa opel',
#        'passat volkswagen', 'astra opel', 'a4 audi', 'c_klasse mercedes_benz',
#        '5er bmw', 'e_klasse mercedes_benz'],
#       dtype='object')

# %%
models_series = pd.Series(represented_models)
models_series
# Out:
# 0           golf volkswagen
# 1                   3er bmw
# 2           polo volkswagen
# 3                corsa opel
# 4         passat volkswagen
# 5                astra opel
# 6                   a4 audi
# 7    c_klasse mercedes_benz
# 8                   5er bmw
# 9    e_klasse mercedes_benz
# dtype: object

# %%
brand_model_database = pd.DataFrame(models_series)
brand_model_database_real = pd.DataFrame(brand_model_database[0].str.split(" ", expand = True))
brand_model_database_real.rename(columns={0: "model" , 1: "brand"}, inplace = True)
brand_model_database_real
# Out:
#       model          brand
# 0      golf     volkswagen
# 1       3er            bmw
# 2      polo     volkswagen
# 3     corsa           opel
# 4    passat     volkswagen
# 5     astra           opel
# 6        a4           audi
# 7  c_klasse  mercedes_benz
# 8       5er            bmw
# 9  e_klasse  mercedes_benz

# %% [markdown]
# I had to concatenate the values in columns model and brand to value count which model was the most common, create a series object and dataframe object and later split that dataframe object to view both columns in a single list.
# Is there a way to do this less code?
#
# The most common brand/model combinations German automaker cars, mainly Volkswagen.
#
# Now to split odometer_km into groups.

# %%
autos["odometer_km"].value_counts()
# Out:
# 150000    28446
# 125000     4719
# 100000     1979
# 90000      1627
# 80000      1347
# 70000      1157
# 60000      1095
# 50000       969
# 40000       784
# 30000       742
# 20000       704
# 5000        579
# 10000       221
# Name: odometer_km, dtype: int64

# %%
odometer_km = (150000,125000,100000,90000,80000,70000,60000,50000,
               40000, 30000, 20000, 10000, 5000)

# %%
def mean_analysis(odometer):
    
    for km in odometer:
    
        km_odometer = autos[autos["odometer_km"] == km]
        brands = km_odometer["brand"].value_counts(normalize = True)
        represented_brands = brands[brands > .015].index
    
        price_mean_by_brand = {}
    
        for b in represented_brands:
            selected_rows = km_odometer[km_odometer["brand"] == b]
            mean = selected_rows["price"].mean()
            price_mean_by_brand[b] = int(mean)
        
        new_series = pd.Series(price_mean_by_brand)
        if km == 150000:
            new_database = pd.DataFrame(new_series, columns=[km])
        elif km != 5000:
            new_database[km] = new_series
        else:
            new_database[km] = new_series
                        
    return new_database

# %%
brands_by_odometer_by_price = mean_analysis(odometer_km)
brands_by_odometer_by_price
# Out:
#                150000  125000  100000  90000   80000   70000   60000   50000   \
# audi             5744   12438   15276   16142   16471   21327   20630   22786
# bmw              5790   11454   13353   14486   16323   17784   19408   23936
# fiat             1758    2481    3299    3588    4542    4657    5125    4814
# ford             2360    4048    4062    4176    6143    6838    6465    7255
# mercedes_benz    5710   10000   14121   15430   16041   17505   20974   22709
# opel             2064    3555    4593    4093    6115    7685    6917    8872
# peugeot          2005    3610    4964    4100    5263    6878    6473    7791
# renault          1671    2496    3281    3833    4128    5774    6960    7145
# seat             2508    4211    5066    6273    7248    8173    9931   10066
# volkswagen       3664    6137    7961    8769   10808   11582   12765   13414
#
#                40000   30000   20000    10000   5000
# audi            26383   26527   27085  28339.0   14146
# bmw             24586   24280   25155  32568.0    8486
# fiat             6870    7636    7993  11306.0    6571
# ford            10776   13076   13255  14971.0    7355
# mercedes_benz   25136   19138   25816  31929.0   13209
# opel             9092   10923    9969  13611.0    5166
# peugeot         10325   11612    5007      NaN    4027
# renault          6701   12561    9519   9233.0    5436
# seat            12133   14811   11945      NaN    9620
# volkswagen      15678   15492   17943  20519.0    5321

# %% [markdown]
# According to the analysis above, it seems cars begin to lose value faster after they reach 30,000 to 50,000 km. Let's see how much value they lose if they have unrepaired damage.

# %%
unrepaired_damage = ("yes", "no", "not_specified")

# %%
def mean_analysis(odometer):
    
    for km in odometer:
    
        km_odometer = autos[autos["unrepaired_damage"] == km]
        brands = km_odometer["brand"].value_counts(normalize = True)
        represented_brands = brands[brands > .02].index
    
        price_mean_by_brand = {}
    
        for b in represented_brands:
            selected_rows = km_odometer[km_odometer["brand"] == b]
            mean = selected_rows["price"].mean()
            price_mean_by_brand[b] = int(mean)
        
        new_series = pd.Series(price_mean_by_brand)
        if km == "yes":
            new_database = pd.DataFrame(new_series, columns=[km])
        elif km != "not_specified":
            new_database[km] = new_series
        else:
            new_database[km] = new_series
                        
    return new_database

# %%
brands_by_damage = mean_analysis(unrepaired_damage)
brands_by_damage
# Out:
#                 yes       no  not_specified
# audi           3430  10904.0         5236.0
# bmw            3701   9384.0         5258.0
# fiat           1488   3530.0         2081.0
# ford           1657   4516.0         2202.0
# mercedes_benz  4033   9585.0         5232.0
# nissan         2256      NaN            NaN
# opel           1646   3747.0         2014.0
# peugeot        1649   3723.0         2223.0
# renault        1383   3187.0         1530.0
# volkswagen     2409   6553.0         3285.0

# %% [markdown]
# According to the above analysis, cars with unspecified damage lose almost half the value of cars that report have no damage. Cars with unrepaired damage have value slightly below that of cars with unspecified damage.
# It's safe to say that cars with unspecified damage do have unrepaired damage.

# %% [markdown]
# ## 10.- Closing commentary
#
# These are my findings after reviewing *eBay Kelinanzeigen* data and doing simple analysis:
#
# * Decided to drop 10% of the data, because either it was outliers or it was not realistic.
# * Cars are sold at a continous pace. It would help my analysis to have data of a complete year to see how seasons affect transactions.
# * German cars tend to sell for more, as Audi, BMW, Mercedes Benz and Volkswagen are in the top positions.
# * The average mileage for the cars in the data was 125,000
# * Data from name column was not easy to interpret, an was left as-is.
# * The most common brand/model combinations are German cars, mainly Volkswagen.
# * Cars begin to lose value faster after they reach 30,000 to 50,000 km.
# * Cars that either have damage or is not specified tend to have less than have the value of cars without it.
#
#
# Take aways:
#
# * If one wants to buy a car, it's better to buy them if they have more than 50,000 km.
# * If one wants to sell a car, it's better to sell it before it reaches 30,000 km.
# * It's better to buy a German car, as it's value remains constant throughout time and have a high resale value.
# * It's better to repair damages or risk losing half of the car's value.
